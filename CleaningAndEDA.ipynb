# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.options.mode.copy_on_write = True

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("hf://datasets/maharshipandya/spotify-tracks-dataset/dataset.csv")
df
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music
#
# [114000 rows x 21 columns]

# %% [markdown]
# Inspect Dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.sample(20)
# Out:
#         Unnamed: 0                track_id                          artists  \
# 107499      107499  45FR60U6pxNbiQkA8BOhBD                        Heaven 17
# 74283        74283  6O1zIickC0YQseSVMGlNq8                      Nação Zumbi
# 59632        59632  1xMkTSgZIZAnsu6a5yqudq                        TarantisT
# 61739        61739  6ETaVPR9qHxY3qvjYE7pEx                            STU48
# 99254        99254  0eei3Q3RLKtA9HkvYCQC7t                    Prateek Kuhad
# 49292        49292  0u5Fl8cHmI22KT1eD87NgU          DJ Jantje;Arjon Oostrom
# 94706        94706  4wAA41xlqHTgiTc9da7xtP                          nilöwh.
# 8475          8475  1a2iF9XymafjRk56q7oCxo               Stevie Ray Vaughan
# 44498        44498  26c8cu0WQJpO1BT3uvDIHI                  Days Of The New
# 65571        65571  0H1Uhrit1CxZzGBgsAz4at  Yuvan Shankar Raja;Dharan Kumar
# 92398        92398  3agQa2P1Kr5YAq58nvIT8t                    Los Teen Tops
# 97240        97240  5Vpa8GM9IcixxH5x3tNfqF                Clayton & Romário
# 90893        90893  0XIgpDeAba8YhM1pvEDkXq                        Los Tukas
# 9157          9157  3QI2FbgxMG42vJjqNEHOP3                          O Rappa
# 67088        67088  4uJnQswt7f4r0tuI37wNFk                             Feid
# 69504        69504  76Oo1LA2llE0OrnHGhbMK7                  Lil J;Alan D;MK
# 26216        26216  2w0gIcqm3WCsD5CAXuSgyd         Maria Cristina Brancucci
# 63718        63718  2i22oi1VStGjxe6uSqxNKt                      sakanaction
# 59965        59965  3j78wdlIk5WfnfddP2qySc                        Nima A.M.
# 82152        82152  4HJc004qYXE9zsG6PfTFFj                      glass beach
#
#                                                album_name  \
# 107499                    The Luxury Gap (Deluxe Version)
# 74283                                         Nação Zumbi
# 59632                                    Distorted Brains
# 61739                               無謀な夢は覚めることがない<Type B>
# 99254                                     Shehron Ke Raaz
# 49292                                 Slopen Tot De Grond
# 94706                                        stay with me
# 8475                         Texas Flood (Legacy Edition)
# 44498                               At Home - Alt Edition
# 65571                Rasaathi Nenja (Madras Gig Season 2)
# 92398   La Gran Coleccion Del 60 Aniversario CBS - Los...
# 97240                            No Churrasco 2 (Ao Vivo)
# 90893                    Tesoros De Coleccion - Los Tukas
# 9157                                              7 Vezes
# 67088                         Feliz Cumpleaños con Perreo
# 44498        0.0300      0.060900          0.000003    0.3010   0.8330
# 65571        0.0475      0.557000          0.000000    0.0746   0.3220
# 92398        0.0793      0.572000          0.000000    0.2530   0.9190
# 97240        0.1510      0.408000          0.000000    0.9240   0.8710
# 90893        0.0345      0.404000          0.000000    0.0702   0.7690
# 9157         0.0259      0.638000          0.008150    0.1540   0.7800
# 67088        0.1740      0.116000          0.000000    0.2190   0.4060
# 69504        0.1460      0.185000          0.000009    0.1070   0.4150
# 26216        0.0452      0.981000          0.001310    0.1030   0.0971
# 63718        0.1750      0.043700          0.000053    0.1990   0.6320
# 59965        0.0280      0.000317          0.826000    0.1050   0.2540
# 82152        0.0468      0.047700          0.000112    0.3670   0.3370
#
#           tempo  time_signature        track_genre
# 107499  119.589               4          synth-pop
# 74283   106.991               4                mpb
# 59632   169.981               4            iranian
# 61739   135.933               4             j-idol
# 99254   122.782               4  singer-songwriter
# 49292   154.942               4          hardstyle
# 94706    86.997               4                sad
# 8475    126.877               4              blues
# 44498    81.935               4             grunge
# 65571    91.999               4              k-pop
# 92398    95.273               4         rockabilly
# 97240    91.547               4          sertanejo
# 90893   107.956               4        rock-n-roll
# 9157     92.978               4             brazil
# 67088   167.764               4              latin
# 69504   136.041               4              malay
# 26216    88.272               5             disney
# 63718   131.965               4             j-rock
# 59965   120.019               4            iranian
# 82152   134.935               4          power-pop

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.select_dtypes('number').describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# 25%         0.472000       2.000000     -10.013000       0.000000
# 50%         0.685000       5.000000      -7.004000       1.000000
# 75%         0.854000       8.000000      -5.003000       1.000000
# max         1.000000      11.000000       4.532000       1.000000
#
#          speechiness   acousticness  instrumentalness       liveness  \
# count  114000.000000  114000.000000     114000.000000  114000.000000
# mean        0.084652       0.314910          0.156050       0.213553
# std         0.105732       0.332523          0.309555       0.190378
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.035900       0.016900          0.000000       0.098000
# 50%         0.048900       0.169000          0.000042       0.132000
# 75%         0.084500       0.598000          0.049000       0.273000
# max         0.965000       0.996000          1.000000       1.000000
#
#              valence          tempo  time_signature
# count  114000.000000  114000.000000   114000.000000
# mean        0.474068     122.147837        3.904035
# std         0.259261      29.978197        0.432621
# min         0.000000       0.000000        0.000000
# 25%         0.260000      99.218750        4.000000
# 50%         0.464000     122.017000        4.000000
# 75%         0.683000     140.071000        4.000000
# max         0.995000     243.372000        5.000000

# %%
#check if there are any missing values in dataset
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#since such a small percentage of the data is missing, we can remove the data with missing values
df_cleaned = df.dropna()

# %%
missing_values = df_cleaned.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# Dataset is now cleaned properly.

# %% [markdown]
# Our group was curious about the factors that affect a song's popularity (i.e. duration, danceability, etc. of a song).

# %%
print(df_cleaned.dtypes)
# Out:
# Unnamed: 0            int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %%
#Perform correlation calculations

numerical_columns = df_cleaned.select_dtypes(include=['float64', 'int64', 'bool']).columns
exclude_columns = ['Unnamed: 0', 'popularity']
numerical_columns = [col for col in numerical_columns if col not in exclude_columns]

correlation_results = {}

for col in numerical_columns:
    correlation = df_cleaned['popularity'].corr(df_cleaned[col])
    correlation_results[col] = correlation

correlation_df = pd.DataFrame.from_dict(correlation_results, orient='index', columns=['Correlation'])

correlation_df
# Out:
#                   Correlation
# duration_ms         -0.007129
# explicit             0.044078
# danceability         0.035444
# energy               0.001053
# key                 -0.003847
# loudness             0.050420
# mode                -0.013948
# speechiness         -0.044930
# acousticness        -0.025458
# instrumentalness    -0.095147
# liveness            -0.005397
# valence             -0.040522
# tempo                0.013212
# time_signature       0.031076

# %%
plt.figure(figsize=(10, 6))
plt.bar(correlation_df.index, correlation_df['Correlation'], edgecolor='black')
plt.title('Factors That Affect Song Popularity')
plt.xlabel('Factors')
plt.ylabel('Correlation')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#check if scatterplot estimates linear relationship
plt.figure(figsize=(8, 6))
plt.scatter(df_cleaned['instrumentalness'], df_cleaned['popularity'], alpha=0.5, edgecolor='black')

plt.title('Popularity vs Instrumentalness')
plt.xlabel('Instrumentalness')
plt.ylabel('Popularity')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_cleaned['loudness'], df_cleaned['popularity'], alpha=0.5, edgecolor = 'black')

plt.title('Popularity vs Loudness')
plt.xlabel('Loudness')
plt.ylabel('Popularity')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
